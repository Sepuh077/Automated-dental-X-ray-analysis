# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import cv2
import os
import pickle

# %%
images_path = '../../data/single_tooth/images/'

images = []
for filename in os.listdir(images_path):
    img = cv2.imread(os.path.join(images_path, filename))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    if img is not None:
        images.append(cv2.resize(img, (50, 100)))

# %%
plt.imshow(images[2])

# %%
images = np.array(images)

# %%
kmeans = KMeans(n_clusters=2, random_state=0)

# %%
kmeans.fit(images.reshape(images.shape[0], -1))
# Out:
# /home/sepuh/workspace/diploma/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=0)

# %%
# kmeans.cluster_centers_[kmeans.labels_[sum([len(pixels[j]) for j in range(i)]) : sum([len(pixels[j]) for j in range(i+1)])]]

# %%
i = -1

# %%
i+=1
print(kmeans.labels_[i])
plt.imshow(images[i])
plt.show()
# Out:
# 1

# %%
# with open(f'kmeans.pkl', 'wb') as file:
#         pickle.dump(kmeans, file)
